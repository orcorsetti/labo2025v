# %% [markdown]
# <a href="https://colab.research.google.com/github/orcorsetti/labo2025v/blob/main/src/ensembles/594_TareaHogar_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 01:59:10 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660381 35.3 1454462    77.7 1454462  77.7
# Vcells 1226627  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5941
PARAM$semilla_primigenia <- 100183

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= 6L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 11, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 0.871962, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.284349,
  num_leaves= 47,
  min_data_in_leaf=100
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("max_bin", lower= 20, upper= 500),
  makeNumericParam("learning_rate", lower= 0.01, upper= 1),
  makeNumericParam("subsample", lower= 0.01, upper= 1),
  makeIntegerParam("n_estimators", lower= 30L, upper= 5000L),
  makeNumericParam("lambda_l1", lower= 0.00000001, upper= 100),
  makeNumericParam("lambda_l2",lower=0.00000001,upper=1000)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 50 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83536
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Nov 03 02:14:51 PM 2025 AUC 0.917874022548863
#
# Mon Nov 03 02:17:37 PM 2025 AUC 0.919192287950692
#
# Mon Nov 03 02:20:29 PM 2025 AUC 0.923760558307961
#
# Mon Nov 03 02:23:09 PM 2025 AUC 0.917574964558212
#
# Mon Nov 03 02:25:53 PM 2025 AUC 0.917618685902665
#
# Mon Nov 03 02:28:45 PM 2025 AUC 0.925562217280083
#
# Mon Nov 03 02:31:22 PM 2025 AUC 0.910851179136723
#
# Mon Nov 03 02:34:03 PM 2025 AUC 0.917497370395289
#
# Mon Nov 03 02:36:46 PM 2025 AUC 0.923376076462462
#
# Mon Nov 03 02:39:34 PM 2025 AUC 0.917855020050129
#
# Mon Nov 03 02:42:22 PM 2025 AUC 0.926713202501887
#
# Mon Nov 03 02:45:02 PM 2025 AUC 0.91518776723685
#
# Mon Nov 03 02:47:43 PM 2025 AUC 0.918904876467468
#
# Mon Nov 03 02:50:23 PM 2025 AUC 0.921913970136946
#
# Mon Nov 03 02:53:03 PM 2025 AUC 0.914916713281436
#
# Mon Nov 03 02:56:07 PM 2025 AUC 0.927521257622843
#
# Mon Nov 03 02:59:37 PM 2025 AUC 0.929067118108867
#
# Mon Nov 03 03:02:32 PM 2025 AUC 0.928165890905718
#
# Mon Nov 03 03:05:10 PM 2025 AUC 0.910804000689729
#
# Mon Nov 03 03:07:57 PM 2025 AUC 0.921452760996847
#
# Mon Nov 03 03:10:40 PM 2025 AUC 0.915543476298273
#
# Mon Nov 03 03:13:18 PM 2025 AUC 0.913791112113668
#
# Mon Nov 03 03:16:10 PM 2025 AUC 0.925679283665022
#
# Mon Nov 03 03:18:55 PM 2025 AUC 0.922519086474522
#
# [mbo] 0: max_bin=411; learning_rate=0.469; subsample=0.325; n_estimators=1527; lambda_l1=64.8; lambda_l2=419 : y = 0.918 : 163.0 secs : initdesign
#
# [mbo] 0: max_bin=335; learning_rate=0.441; subsample=0.226; n_estimators=2043; lambda_l1=60.8; lambda_l2=600 : y = 0.919 : 166.2 secs : initdesign
#
# [mbo] 0: max_bin=457; learning_rate=0.0641; subsample=0.549; n_estimators=698; lambda_l1=41.9; lambda_l2=203 : y = 0.924 : 171.2 secs : initdesign
#
# [mbo] 0: max_bin=310; learning_rate=0.765; subsample=0.898; n_estimators=4834; lambda_l1=55.1; lambda_l2=294 : y = 0.918 : 160.7 secs : initdesign
#
# [mbo] 0: max_bin=168; learning_rate=0.373; subsample=0.855; n_estimators=3326; lambda_l1=76.7; lambda_l2=913 : y = 0.918 : 163.7 secs : initdesign
#
# [mbo] 0: max_bin=227; learning_rate=0.941; subsample=0.531; n_estimators=2804; lambda_l1=10.8; lambda_l2=488 : y = 0.926 : 171.7 secs : initdesign
#
# [mbo] 0: max_bin=151; learning_rate=0.698; subsample=0.449; n_estimators=1827; lambda_l1=80.7; lambda_l2=105 : y = 0.911 : 157.6 secs : initdesign
#
# [mbo] 0: max_bin=382; learning_rate=0.667; subsample=0.108; n_estimators=3041; lambda_l1=69.2; lambda_l2=852 : y = 0.917 : 160.7 secs : initdesign
#
# [mbo] 0: max_bin=252; learning_rate=0.869; subsample=0.929; n_estimators=4439; lambda_l1=27; lambda_l2=730 : y = 0.923 : 163.4 secs : initdesign
#
# [mbo] 0: max_bin=440; learning_rate=0.095; subsample=0.263; n_estimators=2105; lambda_l1=74.3; lambda_l2=526 : y = 0.918 : 167.1 secs : initdesign
#
# [mbo] 0: max_bin=353; learning_rate=0.289; subsample=0.596; n_estimators=568; lambda_l1=18.7; lambda_l2=213 : y = 0.927 : 168.7 secs : initdesign
#
# [mbo] 0: max_bin=98; learning_rate=0.234; subsample=0.77; n_estimators=4115; lambda_l1=90.2; lambda_l2=132 : y = 0.915 : 159.6 secs : initdesign
#
# [mbo] 0: max_bin=470; learning_rate=0.747; subsample=0.676; n_estimators=3618; lambda_l1=52.9; lambda_l2=773 : y = 0.919 : 161.0 secs : initdesign
#
# [mbo] 0: max_bin=36; learning_rate=0.912; subsample=0.386; n_estimators=1296; lambda_l1=36.3; lambda_l2=700 : y = 0.922 : 160.2 secs : initdesign
#
# [mbo] 0: max_bin=116; learning_rate=0.594; subsample=0.823; n_estimators=909; lambda_l1=85.5; lambda_l2=559 : y = 0.915 : 160.3 secs : initdesign
#
# [mbo] 0: max_bin=220; learning_rate=0.515; subsample=0.17; n_estimators=122; lambda_l1=7.8; lambda_l2=397 : y = 0.928 : 183.8 secs : initdesign
#
# [mbo] 0: max_bin=125; learning_rate=0.336; subsample=0.715; n_estimators=1236; lambda_l1=2.42; lambda_l2=937 : y = 0.929 : 210.2 secs : initdesign
#
# [mbo] 0: max_bin=263; learning_rate=0.392; subsample=0.21; n_estimators=4310; lambda_l1=14.7; lambda_l2=636 : y = 0.928 : 174.4 secs : initdesign
#
# [mbo] 0: max_bin=364; learning_rate=0.824; subsample=0.366; n_estimators=3790; lambda_l1=92.6; lambda_l2=290 : y = 0.911 : 158.3 secs : initdesign
#
# [mbo] 0: max_bin=286; learning_rate=0.137; subsample=0.964; n_estimators=2708; lambda_l1=49.6; lambda_l2=340 : y = 0.921 : 167.2 secs : initdesign
#
# [mbo] 0: max_bin=188; learning_rate=0.205; subsample=0.0569; n_estimators=3511; lambda_l1=99.4; lambda_l2=963 : y = 0.916 : 162.5 secs : initdesign
#
# [mbo] 0: max_bin=65; learning_rate=0.978; subsample=0.667; n_estimators=4664; lambda_l1=22.8; lambda_l2=73 : y = 0.914 : 158.5 secs : initdesign
#
# [mbo] 0: max_bin=57; learning_rate=0.0388; subsample=0.043; n_estimators=2393; lambda_l1=31.1; lambda_l2=19.8 : y = 0.926 : 172.2 secs : initdesign
#
# [mbo] 0: max_bin=491; learning_rate=0.577; subsample=0.488; n_estimators=343; lambda_l1=41; lambda_l2=798 : y = 0.923 : 164.7 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:22:21 PM 2025 AUC 0.925053005182153
#
# [mbo] 1: max_bin=248; learning_rate=0.0169; subsample=0.056; n_estimators=2333; lambda_l1=0.00685; lambda_l2=659 : y = 0.925 : 205.1 secs : infill_ei
#
# Mon Nov 03 03:25:57 PM 2025 AUC 0.928916966809384
#
# [mbo] 2: max_bin=237; learning_rate=0.525; subsample=0.603; n_estimators=1602; lambda_l1=1.89; lambda_l2=752 : y = 0.929 : 215.5 secs : infill_ei
#
# Mon Nov 03 03:29:02 PM 2025 AUC 0.929594898292091
#
# [mbo] 3: max_bin=164; learning_rate=0.461; subsample=0.403; n_estimators=2059; lambda_l1=10.1; lambda_l2=955 : y = 0.93 : 183.9 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:32:00 PM 2025 AUC 0.928810471214541
#
# [mbo] 4: max_bin=81; learning_rate=0.373; subsample=0.462; n_estimators=1046; lambda_l1=11.9; lambda_l2=799 : y = 0.929 : 177.6 secs : infill_ei
#
# Mon Nov 03 03:35:38 PM 2025 AUC 0.928671281829986
#
# [mbo] 5: max_bin=251; learning_rate=0.768; subsample=0.379; n_estimators=947; lambda_l1=3.47; lambda_l2=1e+03 : y = 0.929 : 217.1 secs : infill_ei
#
# Mon Nov 03 03:39:08 PM 2025 AUC 0.929078961273322
#
# [mbo] 6: max_bin=93; learning_rate=0.534; subsample=0.477; n_estimators=3279; lambda_l1=0.146; lambda_l2=1e+03 : y = 0.929 : 209.8 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:42:44 PM 2025 AUC 0.930137438051421
#
# [mbo] 7: max_bin=273; learning_rate=0.417; subsample=0.542; n_estimators=2809; lambda_l1=7; lambda_l2=1e+03 : y = 0.93 : 215.5 secs : infill_ei
#
# Mon Nov 03 03:46:18 PM 2025 AUC 0.929484701894257
#
# [mbo] 8: max_bin=255; learning_rate=0.464; subsample=0.962; n_estimators=2997; lambda_l1=7.31; lambda_l2=1e+03 : y = 0.929 : 212.6 secs : infill_ei
#
# Mon Nov 03 03:49:54 PM 2025 AUC 0.929236571291088
#
# [mbo] 9: max_bin=291; learning_rate=0.404; subsample=0.609; n_estimators=4974; lambda_l1=6.64; lambda_l2=1e+03 : y = 0.929 : 216.4 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:53:43 PM 2025 AUC 0.928789117664572
#
# [mbo] 10: max_bin=496; learning_rate=0.459; subsample=0.499; n_estimators=2807; lambda_l1=5.12; lambda_l2=999 : y = 0.929 : 227.5 secs : infill_ei
#
# Mon Nov 03 03:56:57 PM 2025 AUC 0.929011033811602
#
# [mbo] 11: max_bin=207; learning_rate=0.371; subsample=0.604; n_estimators=3189; lambda_l1=9.71; lambda_l2=1e+03 : y = 0.929 : 194.2 secs : infill_ei
#
# Mon Nov 03 04:00:37 PM 2025 AUC 0.929299957493444
#
# [mbo] 12: max_bin=294; learning_rate=0.446; subsample=0.42; n_estimators=2116; lambda_l1=1.99; lambda_l2=998 : y = 0.929 : 218.9 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:04:06 PM 2025 AUC 0.929062356270304
#
# [mbo] 13: max_bin=281; learning_rate=0.566; subsample=0.524; n_estimators=2734; lambda_l1=6.77; lambda_l2=930 : y = 0.929 : 208.7 secs : infill_ei
#
# Mon Nov 03 04:07:33 PM 2025 AUC 0.930587453586165
#
# [mbo] 14: max_bin=65; learning_rate=0.437; subsample=0.483; n_estimators=1925; lambda_l1=5.55; lambda_l2=961 : y = 0.931 : 206.3 secs : infill_ei
#
# Mon Nov 03 04:11:07 PM 2025 AUC 0.928817470895791
#
# [mbo] 15: max_bin=196; learning_rate=0.415; subsample=0.727; n_estimators=2650; lambda_l1=5.65; lambda_l2=602 : y = 0.929 : 212.5 secs : infill_ei
#
# Saved the current state after iteration 16 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:14:36 PM 2025 AUC 0.928591858628028
#
# [mbo] 16: max_bin=46; learning_rate=0.853; subsample=0.998; n_estimators=319; lambda_l1=0.0372; lambda_l2=997 : y = 0.929 : 209.1 secs : infill_ei
#
# Mon Nov 03 04:18:00 PM 2025 AUC 0.929994319819404
#
# [mbo] 17: max_bin=27; learning_rate=0.46; subsample=0.558; n_estimators=472; lambda_l1=5.75; lambda_l2=1e+03 : y = 0.93 : 203.0 secs : infill_ei
#
# Mon Nov 03 04:21:12 PM 2025 AUC 0.927774989869249
#
# [mbo] 18: max_bin=20; learning_rate=0.901; subsample=0.0139; n_estimators=2287; lambda_l1=5.29; lambda_l2=971 : y = 0.928 : 192.0 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:24:41 PM 2025 AUC 0.929909728004743
#
# [mbo] 19: max_bin=38; learning_rate=0.443; subsample=0.722; n_estimators=2364; lambda_l1=0.93; lambda_l2=999 : y = 0.93 : 208.0 secs : infill_ei
#
# Mon Nov 03 04:28:05 PM 2025 AUC 0.92895753549651
#
# [mbo] 20: max_bin=29; learning_rate=0.425; subsample=0.0796; n_estimators=2617; lambda_l1=5.38; lambda_l2=1e+03 : y = 0.929 : 203.7 secs : infill_ei
#
# Mon Nov 03 04:31:36 PM 2025 AUC 0.929679734642018
#
# [mbo] 21: max_bin=91; learning_rate=0.444; subsample=0.578; n_estimators=2071; lambda_l1=5.61; lambda_l2=954 : y = 0.93 : 209.9 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:35:20 PM 2025 AUC 0.930598238847002
#
# [mbo] 22: max_bin=471; learning_rate=0.184; subsample=0.928; n_estimators=4413; lambda_l1=5.43; lambda_l2=669 : y = 0.931 : 223.5 secs : infill_ei
#
# Mon Nov 03 04:38:56 PM 2025 AUC 0.929346237488433
#
# [mbo] 23: max_bin=414; learning_rate=0.0896; subsample=0.832; n_estimators=4431; lambda_l1=5.99; lambda_l2=927 : y = 0.929 : 215.9 secs : infill_ei
#
# Mon Nov 03 04:42:42 PM 2025 AUC 0.929845940205724
#
# [mbo] 24: max_bin=449; learning_rate=0.354; subsample=0.998; n_estimators=2188; lambda_l1=4.19; lambda_l2=557 : y = 0.93 : 225.1 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:46:30 PM 2025 AUC 0.929732636258847
#
# [mbo] 25: max_bin=500; learning_rate=0.301; subsample=0.944; n_estimators=4935; lambda_l1=5.72; lambda_l2=463 : y = 0.93 : 226.8 secs : infill_ei
#
# Mon Nov 03 04:50:12 PM 2025 AUC 0.930023553196442
#
# [mbo] 26: max_bin=373; learning_rate=0.277; subsample=0.999; n_estimators=4277; lambda_l1=0.0556; lambda_l2=684 : y = 0.93 : 221.1 secs : infill_ei
#
# Mon Nov 03 04:53:35 PM 2025 AUC 0.929098647171514
#
# [mbo] 27: max_bin=20; learning_rate=0.408; subsample=0.424; n_estimators=1720; lambda_l1=3.73; lambda_l2=998 : y = 0.929 : 202.8 secs : infill_ei
#
# Saved the current state after iteration 28 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:57:21 PM 2025 AUC 0.929954801151726
#
# [mbo] 28: max_bin=454; learning_rate=0.254; subsample=0.747; n_estimators=3978; lambda_l1=0.00109; lambda_l2=582 : y = 0.93 : 224.6 secs : infill_ei
#
# Mon Nov 03 05:01:07 PM 2025 AUC 0.92968449350132
#
# [mbo] 29: max_bin=479; learning_rate=0.252; subsample=0.998; n_estimators=3555; lambda_l1=5.27; lambda_l2=951 : y = 0.93 : 225.7 secs : infill_ei
#
# Mon Nov 03 05:04:33 PM 2025 AUC 0.929039068565764
#
# [mbo] 30: max_bin=431; learning_rate=0.274; subsample=0.999; n_estimators=4666; lambda_l1=9.18; lambda_l2=630 : y = 0.929 : 204.8 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:08:22 PM 2025 AUC 0.930170225206454
#
# [mbo] 31: max_bin=465; learning_rate=0.376; subsample=0.895; n_estimators=2714; lambda_l1=0.00458; lambda_l2=723 : y = 0.93 : 228.1 secs : infill_ei
#
# Mon Nov 03 05:12:08 PM 2025 AUC 0.929987927742743
#
# [mbo] 32: max_bin=458; learning_rate=0.169; subsample=0.934; n_estimators=3206; lambda_l1=0.0714; lambda_l2=481 : y = 0.93 : 225.5 secs : infill_ei
#
# Mon Nov 03 05:15:38 PM 2025 AUC 0.928765118392488
#
# [mbo] 33: max_bin=62; learning_rate=0.516; subsample=0.503; n_estimators=642; lambda_l1=0.1; lambda_l2=997 : y = 0.929 : 209.6 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:19:20 PM 2025 AUC 0.929018428935612
#
# [mbo] 34: max_bin=391; learning_rate=0.451; subsample=0.897; n_estimators=35; lambda_l1=5.02; lambda_l2=633 : y = 0.929 : 221.8 secs : infill_ei
#
# Mon Nov 03 05:22:14 PM 2025 AUC 0.926313041772383
#
# [mbo] 35: max_bin=257; learning_rate=0.23; subsample=0.191; n_estimators=151; lambda_l1=26.7; lambda_l2=995 : y = 0.926 : 173.0 secs : infill_ei
#
# Mon Nov 03 05:25:51 PM 2025 AUC 0.929059181591387
#
# [mbo] 36: max_bin=262; learning_rate=0.228; subsample=0.485; n_estimators=4216; lambda_l1=5.36; lambda_l2=600 : y = 0.929 : 216.8 secs : infill_ei
#
# Saved the current state after iteration 37 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:29:17 PM 2025 AUC 0.930178842064895
#
# [mbo] 37: max_bin=26; learning_rate=0.396; subsample=0.903; n_estimators=4411; lambda_l1=1.05; lambda_l2=1e+03 : y = 0.93 : 204.6 secs : infill_ei
#
# Mon Nov 03 05:33:02 PM 2025 AUC 0.930416611393357
#
# [mbo] 38: max_bin=500; learning_rate=0.135; subsample=0.817; n_estimators=1731; lambda_l1=5.54; lambda_l2=667 : y = 0.93 : 224.7 secs : infill_ei
#
# Mon Nov 03 05:36:50 PM 2025 AUC 0.930086910720929
#
# [mbo] 39: max_bin=499; learning_rate=0.211; subsample=0.891; n_estimators=4332; lambda_l1=2.99; lambda_l2=682 : y = 0.93 : 227.5 secs : infill_ei
#
# Saved the current state after iteration 40 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:40:38 PM 2025 AUC 0.930271630820454
#
# [mbo] 40: max_bin=463; learning_rate=0.282; subsample=0.723; n_estimators=1661; lambda_l1=5.54; lambda_l2=689 : y = 0.93 : 226.8 secs : infill_ei
#
# Mon Nov 03 05:44:02 PM 2025 AUC 0.92995769339686
#
# [mbo] 41: max_bin=49; learning_rate=0.473; subsample=0.831; n_estimators=1877; lambda_l1=6.62; lambda_l2=1e+03 : y = 0.93 : 203.3 secs : infill_ei
#
# Mon Nov 03 05:47:47 PM 2025 AUC 0.92880395685927
#
# [mbo] 42: max_bin=450; learning_rate=0.182; subsample=0.931; n_estimators=2073; lambda_l1=5.81; lambda_l2=664 : y = 0.929 : 224.8 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:51:38 PM 2025 AUC 0.926933058334864
#
# [mbo] 43: max_bin=492; learning_rate=0.367; subsample=0.713; n_estimators=708; lambda_l1=3.54; lambda_l2=320 : y = 0.927 : 230.0 secs : infill_ei
#
# Mon Nov 03 05:55:22 PM 2025 AUC 0.930874060939755
#
# [mbo] 44: max_bin=500; learning_rate=0.0926; subsample=0.764; n_estimators=3812; lambda_l1=5.76; lambda_l2=583 : y = 0.931 : 222.8 secs : infill_ei
#
# Mon Nov 03 05:58:55 PM 2025 AUC 0.922550647353196
#
# [mbo] 45: max_bin=479; learning_rate=0.0107; subsample=0.958; n_estimators=4834; lambda_l1=4.49; lambda_l2=539 : y = 0.923 : 212.7 secs : infill_ei
#
# Saved the current state after iteration 46 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:02:41 PM 2025 AUC 0.929427009562762
#
# [mbo] 46: max_bin=499; learning_rate=0.142; subsample=0.696; n_estimators=3924; lambda_l1=7.19; lambda_l2=522 : y = 0.929 : 224.7 secs : infill_ei
#
# Mon Nov 03 06:06:29 PM 2025 AUC 0.927684897497547
#
# [mbo] 47: max_bin=396; learning_rate=0.88; subsample=0.526; n_estimators=664; lambda_l1=0.066; lambda_l2=967 : y = 0.928 : 226.7 secs : infill_ei
#
# Mon Nov 03 06:10:10 PM 2025 AUC 0.930167192534673
#
# [mbo] 48: max_bin=428; learning_rate=0.126; subsample=0.776; n_estimators=3226; lambda_l1=5.13; lambda_l2=725 : y = 0.93 : 220.0 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:13:56 PM 2025 AUC 0.930005289116829
#
# [mbo] 49: max_bin=500; learning_rate=0.111; subsample=0.877; n_estimators=4183; lambda_l1=0.428; lambda_l2=367 : y = 0.93 : 225.3 secs : infill_ei
#
# Mon Nov 03 06:17:21 PM 2025 AUC 0.930740883586456
#
# [mbo] 50: max_bin=76; learning_rate=0.0997; subsample=0.958; n_estimators=3711; lambda_l1=0.196; lambda_l2=902 : y = 0.931 : 204.5 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "max_bin"       "learning_rate" "subsample"     "n_estimators"
#  [5] "lambda_l1"     "lambda_l2"     "y"             "dob"
#  [9] "eol"           "error.message" "exec.time"     "ei"
# [13] "error.model"   "train.time"    "prop.type"     "propose.time"
# [17] "se"            "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    max_bin learning_rate subsample n_estimators lambda_l1 lambda_l2
#      <int>         <num>     <num>        <int>     <num>     <num>
# 1:     500    0.09260574 0.7644255         3812  5.755278  582.6234
# [1] 0.9308741

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100183
#
# $max_depth
# [1] 6
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 11
#
# $lambda_l1
# [1] 5.755278
#
# $lambda_l2
# [1] 582.6234
#
# $max_bin
# [1] 500
#
# $bagging_fraction
# [1] 0.871962
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.09260574
#
# $feature_fraction
# [1] 0.284349
#
# $num_leaves
# [1] 47
#
# $min_data_in_leaf
# [1] 100
#
# $subsample
# [1] 0.7644255
#
# $n_estimators
# [1] 3812

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 06:23:36 PM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
